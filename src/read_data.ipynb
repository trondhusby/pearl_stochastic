# %%
import cbsodata
import pandas

mig_data = pandas.DataFrame(cbsodata.get_data('60048ned', filters="RegioS eq 'GM0363'"))

pop_data =

# %%
mig_data
# Out:
#       ID     RegioS Perioden  BinnenGemeentenVerhuisdePersonen_1  \
# 0   2752  Amsterdam     1988                               80609
# 1   2753  Amsterdam     1989                               83282
# 2   2754  Amsterdam     1990                               85187
# 3   2755  Amsterdam     1991                               86462
# 4   2756  Amsterdam     1992                               94654
# 5   2757  Amsterdam     1993                               91668
# 6   2758  Amsterdam     1994                               89043
# 7   2759  Amsterdam     1995                               82256
# 8   2760  Amsterdam     1996                               76612
# 9   2761  Amsterdam     1997                               78667
# 10  2762  Amsterdam     1998                               79448
# 11  2763  Amsterdam     1999                               74487
# 12  2764  Amsterdam     2000                               64071
# ...
